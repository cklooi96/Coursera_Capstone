# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods
#
# #### This notebook contains multiple parts:
# 1. A description of the problem and a discussion of the background - Week 1 (Completed)
# 2. A description of the data and how it will be used to solve the problem - Week 1 (Completed)
# 3. Methodology and Exploratory Data Analysis - Week 2
# 4. Inferences and Discussion - Week 2
#
# The seperate report goes into more decription of the methodology. This notebook gives only brief outlines of the methodology of each step, but includes all the code, dataframes and visualisations.

# %% [markdown]
# ## Italian Restaurant

# %% [markdown]
# ### 1. Introduction and Discussion of the Business Objective and Problem
# #### "Where would you recommend me to open an Italian Restaurant in the city of New York?"
#
#
# #### Background & Task on Hand
# Technomic (2015) recently compiled a list of the most crowd-pleasing ethnic cuisines for Parade Magazine. Italian is only 3rd most popular cuisine in US, behind Chinese (or rather American Chinese variety) and Mexican cuisines. About 71% of people polled named these 3 as their top favorite, leaving competition far behind. The Italian Restaurants industry is mature, providing a widely accepted cuisine to downstream consumers. Revenue growth is primarily determined by demand from households, which is ultimately driven by consumer spending and preferences. In turn, the industry has grown substantially over the five years to 2018 as the improving economy and rising consumer spending have led to consistent growth in sales (IBISWorld, 2018). Over the five years to 2023, industry revenue is expected to continue growing, albeit at a slower pace when compared with the previous period. This growth can be partially attributed to rising per capita disposable incomes and, subsequently, higher levels of consumer spending.
#
#
# My boss, the stakeholder wants to open a new Italian restaurant as company's new business. I've been given the exciting task of assisting them to make data-driven decisions on the new locations that are most suitable for their new restaurant in New York city. This will be a major part of their decision-making process, the other being on the ground qualitative analysis of districts once this data and report are reviewed and studied.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Criteria
# Increase likelihood of success: Low Competiion, Good Average Rating of Italian Restaurant in Neighborhood.
# #### Why Data?
# Without leveraging data to make decisions about new store locations, the company could spend countless hours walking around districts, consulting many real estate agents with their own district biases, and end up opening in yet another location that is not ideal.
# Data will provide better answers and better solutions to their task at hand.

# %% [markdown]
# ### 2. The Data Science Workflow
# In order to answer the above questions, data on New York City neighborhoods, boroughs to include boundaries, latitude, longitude, restaurants, and restaurant ratings and tips are required.
#
# New York City data containing the neighborhoods and boroughs, latitudes, and longitudes will be obtained from the data source: https://cocl.us/new_york_dataset
#
# New York City data containing neighborhood boundaries will be obtained from the data source: https://data.cityofnewyork.us/City-Government/Borough-Boundaries/tqmj-j8zm
#
# All data related to locations and quality of Italian restaurants will be obtained via the FourSquare API utilized via the Request library in Python

# %% [markdown]
# #### An Overview of Data Science Workflow
#
# 1. Obtain the Data: Research and find suitable sources for the district data for New York city; Access and explore the data to determine if it can be manipulated for our purposes.
#
# 2. Initial Data Wrangling and Cleaning: Clean the data and convert to a useable form as a dataframe.
#
# 3. Data Analysis and Location Data: Foursquare location data will be leveraged to explore or compare districts around New York city; Data manipulation and analysis to derive subsets of the initial data; Identifying the high traffic areas using data visualisation and tatistical analysis.
#
# 4. Visualization:Analysis and plotting visualizations; Data visualization using various mapping libraries.
#
# 5. Discussion and Conclusions: Recomendations and results based on the data analysis; Discussion of any limitations and how the results can be used, and any conclusions that can be drawn.
